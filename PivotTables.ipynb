# %%
import numpy as np
import pandas as pd

# %%
#PIVOT-TABLE

# %%
data = {
    'Date': pd.date_range('2026-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)
df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2026-01-01       A   East    382     24   John  January      Q1
# 1  2026-01-02       B   West    360     77   Mary  January      Q1
# 2  2026-01-03       C  North    774     95    Bob  January      Q1
# 3  2026-01-04       D  South    463     85  Alice  January      Q1
# 4  2026-01-05       A   East    636     66   John  January      Q1
# 5  2026-01-06       B   West    813     43   Mary  January      Q1
# 6  2026-01-07       C  North    259     41    Bob  January      Q1
# 7  2026-01-08       D  South    445     70  Alice  January      Q1
# 8  2026-01-09       A   East    959     76   John  January      Q1
# 9  2026-01-10       B   West    257     47   Mary  January      Q1
# 10 2026-01-11       C  North    585     38    Bob  January      Q1
# 11 2026-01-12       D  South    499     72  Alice  January      Q1
# 12 2026-01-13       A   East    562     22   John  January      Q1
# 13 2026-01-14       B   West    747     58   Mary  January      Q1
# 14 2026-01-15       C  North    478     57    Bob  January      Q1
# 15 2026-01-16       D  South    135     91  Alice  January      Q1
# 16 2026-01-17       A   East    849     95   John  January      Q1
# 17 2026-01-18       B   West    550     72   Mary  January      Q1
# 18 2026-01-19       C  North    411     50    Bob  January      Q1
# 19 2026-01-20       D  South    139     49  Alice  January      Q1

# %%
pd.pivot_table(df,values='Sales',index='Region',columns='Product',aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     636.0    NaN    NaN    NaN
# North      NaN    NaN  478.0    NaN
# South      NaN    NaN    NaN  445.0
# West       NaN  550.0    NaN    NaN

# %%
pivot2=pd.pivot_table(df,values=['Sales','Units'],index='Region',columns='Product',aggfunc='median')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     636.0    NaN    NaN    NaN  66.0   NaN   NaN   NaN
# North      NaN    NaN  478.0    NaN   NaN   NaN  50.0   NaN
# South      NaN    NaN    NaN  445.0   NaN   NaN   NaN  72.0
# West       NaN  550.0    NaN    NaN   NaN  58.0   NaN   NaN

# %%
#CROSS TABS

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
