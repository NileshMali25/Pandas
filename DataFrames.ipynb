# %%
import numpy as np
import pandas as pd

# %%
#CREATING A DATAFRAME

# %%
data={
    'Name':['John','Lucky','Max','Ronny'],
    'Age':[18,21,28,30],
    'City':['Pune','Mumbai','Nagpur','Nashik'],
    'Salary':[90000,86000,50000,45000]
}
df=pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age    City  Salary
# 0   John   18    Pune   90000
# 1  Lucky   21  Mumbai   86000
# 2    Max   28  Nagpur   50000
# 3  Ronny   30  Nashik   45000

# %%
data_list=[
    ['John',18,'Pune',90000],
    ['Lucky',21,'Mumbai',86000],
    ['Max',28,'Nagpur',50000],
    ['Ronny',30,'Nashik',45000]
]
df2=pd.DataFrame(data_list)
columns=['Name','Age','City','Salary']
df2=pd.DataFrame(data_list,columns=columns)
df2
# Out:
#     Name  Age    City  Salary
# 0   John   18    Pune   90000
# 1  Lucky   21  Mumbai   86000
# 2    Max   28  Nagpur   50000
# 3  Ronny   30  Nashik   45000

# %%
#SELECTION AND INDEXING OF COLUMNS

# %%
df['Name']
# Out:
# 0     John
# 1    Lucky
# 2      Max
# 3    Ronny
# Name: Name, dtype: object

# %%
df[['Name','City']]
# Out:
#     Name    City
# 0   John    Pune
# 1  Lucky  Mumbai
# 2    Max  Nagpur
# 3  Ronny  Nashik

# %%
#CREATING A NEW COLUMN

# %%
df2['Designation']=['Doctor','Eng.','Doctor','Eng.']

# %%
df2
# Out:
#     Name  Age    City  Salary Designation
# 0   John   18    Pune   90000      Doctor
# 1  Lucky   21  Mumbai   86000        Eng.
# 2    Max   28  Nagpur   50000      Doctor
# 3  Ronny   30  Nashik   45000        Eng.

# %%
#REMOVING COLUMN

# %%
df2.drop('Designation',axis=1,inplace=True) #permenant delete

# %%
df2
# Out:
#     Name  Age    City  Salary
# 0   John   18    Pune   90000
# 1  Lucky   21  Mumbai   86000
# 2    Max   28  Nagpur   50000
# 3  Ronny   30  Nashik   45000

# %%
df2.drop(['Salary','City'],axis=1) #Temporary delete
# Out:
#     Name  Age
# 0   John   18
# 1  Lucky   21
# 2    Max   28
# 3  Ronny   30

# %%
df2.drop(0,axis=0)
# Out:
#     Name  Age    City  Salary
# 1  Lucky   21  Mumbai   86000
# 2    Max   28  Nagpur   50000
# 3  Ronny   30  Nashik   45000

# %%
#SELECTING ROWS

# %%
df2.loc[[0,1]]
# Out:
#     Name  Age    City  Salary
# 0   John   18    Pune   90000
# 1  Lucky   21  Mumbai   86000

# %%
df2.iloc[3]
# Out:
# Name       Ronny
# Age           30
# City      Nashik
# Salary     45000
# Name: 3, dtype: object

# %%
#SELECTING SUBSETS OF ROWS AND COLUMNS

# %%
df2.loc[[0,1]][['Name','City']]
# Out:
#     Name    City
# 0   John    Pune
# 1  Lucky  Mumbai

# %%
#CONDITIONAL SELECTION

# %%
#I ONLY WANT TO SEE THOSE PEOPLE WHOSE AGE IS ABOVE OR EQUAL TO 20
df2[df2['Age'] >=20]
# Out:
#     Name  Age    City  Salary
# 1  Lucky   21  Mumbai   86000
# 2    Max   28  Nagpur   50000
# 3  Ronny   30  Nashik   45000

# %%
#I ONLY WANT TO SEE THOSE PEOPLE WHOSE AGE IS ABOVE OR EQUAL TO 20 AND THERE CITY MUST BE MUMBAI
df2[(df2['Age'] > 20) & (df2['City']=='Mumbai')]
# Out:
#     Name  Age    City  Salary
# 1  Lucky   21  Mumbai   86000
